# %% [markdown]
# # Bike store sales

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Loading our Data

# %%
sales = pd.read_csv("sales_data.csv")

# %%
sales.head(10) # displaying the first 10 rows in the dataset
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
# 5  2016-05-15   15       May  2016            47  Adults (35-64)
# 6  2014-05-22   22       May  2014            47  Adults (35-64)
# 7  2016-05-22   22       May  2016            47  Adults (35-64)
# 8  2014-02-22   22  February  2014            35  Adults (35-64)
# 9  2016-02-22   22  February  2016            35  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
sales.tail(10) # displaying the last 10 rows in the dataset
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 113026  2013-07-08    8      July  2013            29  Young Adults (25-34)
# 113027  2015-07-08    8      July  2015            29  Young Adults (25-34)
# 113028  2013-12-28   28  December  2013            41        Adults (35-64)
# 113029  2015-12-28   28  December  2015            41        Adults (35-64)
# 113030  2014-04-12   12     April  2014            41        Adults (35-64)
# 113031  2016-04-12   12     April  2016            41        Adults (35-64)
# 113032  2014-04-02    2     April  2014            18           Youth (<25)
# 113033  2016-04-02    2     April  2016            18           Youth (<25)
# 113034  2014-03-04    4     March  2014            37        Adults (35-64)
# 113035  2016-03-04    4     March  2016            37        Adults (35-64)
#
#        Customer_Gender         Country          State Product_Category  \
# ...

# %%
sales["Unit_Cost"].unique() # checking the unique items found in the Unit_Cost column in the dataset
# Out:
# array([  45,   59,    4,    2,    3,    7,    8,    9,   13,   21,   42,
#          38, 1912, 1898, 1266, 1252,  420,  308,  295, 2171,  344, 1083,
#        1555,  713, 1519,  487,   26,    1,   11,   12, 1482,  461,  755,
#          24], dtype=int64)

# %%
sales["Date"].unique() # checking the unique items found in the Date column in the dataset
# Out:
# array(['2013-11-26', '2015-11-26', '2014-03-23', ..., '2015-01-06',
#        '2012-02-20', '2011-02-20'], dtype=object)

# %%
sales["Age_Group"].unique() # checking the unique items found in the Age_Group column in the dataset

# This shows that there are four age groups; youths, young adults, adults and seniors respectively
# Out:
# array(['Youth (<25)', 'Adults (35-64)', 'Young Adults (25-34)',
#        'Seniors (64+)'], dtype=object)

# %%
sales["Cost"].unique() # checking the unique items found in the Cost column in the dataset
# Out:
# array([  360,  1035,   900,   180,   225,    90,   990,   945,   315,
#           45,   270,   405,   135,  1080,  1125,   450,   495,   540,
#          630,  1260,  1215,   675,   585,   765,   720,  1350,  1305,
#         1170,   855,   810,   590,   472,   413,   531,   354,   236,
#          118,    59,   177,   295,   649,   708,    12,    60,    52,
#           32,    56,    44,    40,    34,    20,    24,    54,    48,
#           50,    30,    28,    58,     8,    66,    18,    57,    36,
#           14,    38,     4,    88,   116,   104,    69,    75,    93,
#           39,    63,     3,     6,    16,    10,    72,    80,   120,
#          112,    92,     2,    22,    26,    42,    46,    27,    84,
#           33,    15,   108,    96,     9,    21,   100,    68,    87,
#           81,    51,    62,    78,    76,    64,   128,   124,   147,
#          154,    91,    70,   182,   175,   168,   119,   189,   105,
# ...

# %%
sales["Country"].unique()

# This shows that sales were done in Canada, Australia, United States, Germany, France and, the United Kingdom
# Out:
# array(['Canada', 'Australia', 'United States', 'Germany', 'France',
#        'United Kingdom'], dtype=object)

# %%
sales["Customer_Age"].unique() # checking the unique items found in the Customer_Age column in the dataset
# Out:
# array([19, 49, 47, 35, 32, 34, 29, 51, 48, 43, 61, 57, 38, 52, 24, 23, 26,
#        54, 46, 41, 33, 42, 45, 53, 21, 22, 67, 31, 37, 87, 25, 40, 44, 55,
#        50, 59, 17, 27, 28, 36, 56, 58, 30, 18, 62, 39, 64, 63, 20, 60, 84,
#        68, 65, 73, 69, 66, 75, 76, 78, 71, 72, 82, 86, 77, 74, 85, 81, 80,
#        70, 79], dtype=int64)

# %%
sales["Customer_Gender"].unique() # checking the unique items found in the Customer_Gender column in the dataset
# Out:
# array(['M', 'F'], dtype=object)

# %%
sales["Day"].unique() # checking the unique items found in the Day column in the dataset
# Out:
# array([26, 23, 15, 22, 30,  2, 17, 27, 25, 13, 19, 11, 31, 28,  7, 24,  3,
#         4, 10, 12,  6, 20, 29, 16, 14, 18,  9,  8,  5,  1, 21],
#       dtype=int64)

# %%
sales["Month"].unique() # checking the unique items found in the Month column in the dataset

# This shows that sales happened all year round
# Out:
# array(['November', 'March', 'May', 'February', 'July', 'August',
#        'September', 'January', 'December', 'June', 'October', 'April'],
#       dtype=object)

# %%
sales["Order_Quantity"].unique() # checking the unique items found in the Order_Quantity column in the dataset
# Out:
# array([ 8, 23, 20,  4,  5,  2, 22, 21,  7,  1,  6,  9,  3, 24, 25, 10, 11,
#        12, 14, 28, 27, 15, 13, 17, 16, 30, 29, 26, 19, 18, 31, 32],
#       dtype=int64)

# %%
sales["Product"].unique() # checking the unique items found in the Product column in the dataset

# This section shows alla the different items sold in the store
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales["Product_Category"].unique() # checking the unique items found in the Product_Category column in the dataset

# This shows the different categories of product items in the store
# Out:
# array(['Accessories', 'Clothing', 'Bikes'], dtype=object)

# %%
sales["Profit"].unique() # checking the unique items found in the Profit column in the dataset
# Out:
# array([ 590, 1366, 1188, ...,  973, 1161,  786], dtype=int64)

# %%
sales["Revenue"].unique() # checking the unique items found in the Revenue column in the dataset
# Out:
# array([ 950, 2401, 2088, ..., 1905, 1488, 1428], dtype=int64)

# %%
sales["State"].unique() # checking the unique items found in the State column in the dataset
# Out:
# array(['British Columbia', 'New South Wales', 'Victoria', 'Oregon',
#        'California', 'Saarland', 'Seine Saint Denis', 'Moselle',
#        'Queensland', 'England', 'Nord', 'Washington', 'Hessen',
#        'Nordrhein-Westfalen', 'Hamburg', 'Loir et Cher', 'Kentucky',
#        'Seine (Paris)', 'South Australia', 'Loiret', 'Alberta', 'Bayern',
#        'Hauts de Seine', 'Yveline', 'Essonne', "Val d'Oise", 'Tasmania',
#        'Seine et Marne', 'Val de Marne', 'Pas de Calais',
#        'Charente-Maritime', 'Garonne (Haute)', 'Brandenburg', 'Texas',
#        'New York', 'Florida', 'Somme', 'Illinois', 'South Carolina',
#        'North Carolina', 'Georgia', 'Virginia', 'Ohio', 'Ontario',
#        'Wyoming', 'Missouri', 'Montana', 'Utah', 'Minnesota',
#        'Mississippi', 'Massachusetts', 'Arizona', 'Alabama'], dtype=object)

# %%
sales["Sub_Category"].unique() # checking the unique items found in the Sub_Category column in the dataset
# Out:
# array(['Bike Racks', 'Bike Stands', 'Bottles and Cages', 'Caps',
#        'Cleaners', 'Fenders', 'Gloves', 'Helmets', 'Hydration Packs',
#        'Jerseys', 'Mountain Bikes', 'Road Bikes', 'Shorts', 'Socks',
#        'Tires and Tubes', 'Touring Bikes', 'Vests'], dtype=object)

# %%
sales["Unit_Price"].unique() # checking the unique items found in the Unit_Price column in the dataset
# Out:
# array([ 120,  159,   10,    5,    9,    8,   22,   24,   35,   55,   54,
#          50, 3400, 3375, 2320, 2295,  769,  565,  540, 3578, 1701, 2443,
#        1120,  783,   70,    2,   25,    4,   21,   29,   30,   33, 2384,
#         742, 1215,   64], dtype=int64)

# %%
sales["Year"].unique() # checking the unique items found in the Year column in the dataset
# Out:
# array([2013, 2015, 2014, 2016, 2012, 2011], dtype=int64)

# %%
sales.shape
# Out:
# (113036, 18)

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales.loc[sales["Product_Category"] == "Accessories"].head(10)
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
# 5  2016-05-15   15       May  2016            47  Adults (35-64)
# 6  2014-05-22   22       May  2014            47  Adults (35-64)
# 7  2016-05-22   22       May  2016            47  Adults (35-64)
# 8  2014-02-22   22  February  2014            35  Adults (35-64)
# 9  2016-02-22   22  February  2016            35  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
sales.loc[sales["Product_Category"] == "Clothing"].head(10)
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 16924  2013-07-20   20      July  2013            32  Young Adults (25-34)
# 16925  2015-07-20   20      July  2015            32  Young Adults (25-34)
# 16926  2013-11-24   24  November  2013            51        Adults (35-64)
# 16927  2015-11-24   24  November  2015            51        Adults (35-64)
# 16928  2014-02-05    5  February  2014            51        Adults (35-64)
# 16929  2016-02-05    5  February  2016            51        Adults (35-64)
# 16930  2014-05-12   12       May  2014            50        Adults (35-64)
# 16931  2016-05-12   12       May  2016            50        Adults (35-64)
# 16932  2014-05-11   11       May  2014            50        Adults (35-64)
# 16933  2016-05-11   11       May  2016            50        Adults (35-64)
#
#       Customer_Gender    Country            State Product_Category  \
# 16924               M  Australia         Victoria         Clothing
# ...

# %%
sales.loc[sales["Product_Category"] == "Bikes"].head(10)
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 49304  2013-01-28   28   January  2013            31  Young Adults (25-34)
# 49305  2015-01-28   28   January  2015            31  Young Adults (25-34)
# 49306  2013-07-22   22      July  2013            31  Young Adults (25-34)
# 49307  2015-07-22   22      July  2015            31  Young Adults (25-34)
# 49308  2013-12-25   25  December  2013            31  Young Adults (25-34)
# 49309  2015-12-25   25  December  2015            31  Young Adults (25-34)
# 49310  2014-02-13   13  February  2014            31  Young Adults (25-34)
# 49311  2016-02-13   13  February  2016            31  Young Adults (25-34)
# 49312  2013-07-04    4      July  2013            32  Young Adults (25-34)
# 49313  2015-07-04    4      July  2015            32  Young Adults (25-34)
#
#       Customer_Gender    Country       State Product_Category    Sub_Category  \
# ...

# %% [markdown]
# # Numerical analysis and visualization

# %%
sales["Unit_Cost"].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
sales["Unit_Cost"].mean()
# Out:
# 267.296365759581

# %%
sales["Unit_Cost"].median()
# Out:
# 9.0

# %%
sales["Unit_Cost"].plot(kind = "box", vert = False, figsize = (14, 6))
# Out:
# <Axes: >

# %%
sales["Unit_Cost"].plot(kind = "density", figsize = (14, 6))
# Out:
# <Axes: ylabel='Density'>

# %%
# Pairplot of all features

sns.pairplot(data = sales, corner = True)
# Out:
# C:\Users\Elitebook\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# correlation heatmap

plt.figure(figsize = (20, 20))
sns.heatmap(sales, annot = True, cmap='viridis')
plt.title("Heatmap of the dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 5
#       3 data = sales
#       4 plt.figure(figsize = (20, 20))
# ----> 5 sns.heatmap(sales.corr(), annot = True)
#       6 plt.title("Heatmap of the dataset")
#       7 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# # Categorical analysis and visualizations
